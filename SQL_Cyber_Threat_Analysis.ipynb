# %% [markdown]
# <a href="https://colab.research.google.com/github/24NAVEENOS12/Development-of-Interactive-Cyber-Threat-Visualization-Dashboard/blob/main/SQL_Cyber_Threat_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SQL Task – Cyber Threat Data Analysis**

# %%
import sqlite3

# Create an in-memory SQLite database connection
conn = sqlite3.connect(':memory:')

# Write the DataFrame to a SQLite table
df.to_sql('cybersecurity_incidents', conn, index=False, if_exists='replace')

print("SQLite database created and DataFrame loaded into 'cybersecurity_incidents' table.")
# Out:
# SQLite database created and DataFrame loaded into 'cybersecurity_incidents' table.

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# Define lists for categorical data to ensure consistency
attack_types = ['Phishing', 'Malware', 'Ransomware', 'DDoS', 'Insider Threat', 'SQL Injection', 'XSS', 'Brute Force', 'Zero-day Exploit', 'Man-in-the-Middle']
attack_vectors = ['Email', 'Network Vulnerability', 'Web Application', 'Physical Access', 'Cloud Misconfiguration', 'IoT Device']
severities = ['Low', 'Medium', 'High', 'Critical']
source_countries = ['USA', 'China', 'Russia', 'North Korea', 'Iran', 'Germany', 'UK', 'India', 'Brazil', 'Canada']
target_countries = ['USA', 'Canada', 'UK', 'Germany', 'France', 'Australia', 'Japan', 'South Korea']
operating_systems = ['Windows Server 2019', 'Windows 10', 'Linux (Ubuntu)', 'Linux (RedHat)', 'macOS', 'Android', 'iOS']
device_types = ['Workstation', 'Server', 'Medical Device', 'IoT Sensor', 'Network Router', 'Cloud Instance', 'Database Server']
target_systems = ['Electronic Health Records (EHR)', 'Billing System', 'Patient Monitoring', 'Radiology PACS', 'Laboratory Information System (LIS)', 'Network Infrastructure']
protocols = ['HTTP', 'HTTPS', 'FTP', 'SFTP', 'SSH', 'RDP', 'DICOM', 'HL7']
ports = ['80', '443', '21', '22', '3389', '1433', '25', '53', '445']
statuses = ['Detected', 'Mitigated', 'Ongoing', 'Containment', 'Eradicated', 'Recovered']
detected_by_options = ['SIEM', 'IDS/IPS', 'Firewall', 'Antivirus', 'User Report', 'Threat Intelligence', 'Security Team']
impact_levels = ['Data Breach', 'System Downtime', 'Financial Loss', 'Reputational Damage', 'Operational Disruption', 'Patient Care Interruption']
mitigation_actions = ['Isolate System', 'Patch Vulnerability', 'Block IP', 'Reset Passwords', 'Restore from Backup', 'Incident Response Plan Executed', 'Forensic Investigation']

# Number of records
num_records = 350 # More than 300

# Generate data
data = {
    'incident_id': [f'INC{i:05d}' for i in range(1, num_records + 1)],
    'timestamp': [
        (datetime.now() - timedelta(days=random.randint(0, 365), hours=random.randint(0, 23), minutes=random.randint(0, 59)))
        .strftime('%Y-%m-%d %H:%M:%S') for _ in range(num_records)
    ],
    'attack_type': random.choices(attack_types, k=num_records),
    'attack_vector': random.choices(attack_vectors, k=num_records),
    'severity': random.choices(severities, weights=[0.4, 0.3, 0.2, 0.1], k=num_records),
    'source_country': random.choices(source_countries, k=num_records),
    'target_country': random.choices(target_countries, k=num_records),
    'source_ip': [f'{random.randint(1, 254)}.{random.randint(0, 254)}.{random.randint(0, 254)}.{random.randint(1, 254)}' for _ in range(num_records)],
    'device_affected': random.choices(device_types, k=num_records),
    'operating_system': random.choices(operating_systems, k=num_records),
    'target_system': random.choices(target_systems, k=num_records),
    'protocol': random.choices(protocols, k=num_records),
    'port': random.choices(ports, k=num_records),
    'status': random.choices(statuses, k=num_records),
    'detected_by': random.choices(detected_by_options, k=num_records),
    'impact_level': random.choices(impact_levels, k=num_records),
    'mitigation_action': random.choices(mitigation_actions, k=num_records),
}

# Create DataFrame
df = pd.DataFrame(data)

# Ensure realism for certain columns
# For example, if attack_type is Ransomware, impact_level is likely System Downtime or Data Breach
for i in range(num_records):
    if df.loc[i, 'attack_type'] == 'Ransomware':
        df.loc[i, 'impact_level'] = random.choice(['System Downtime', 'Data Breach', 'Operational Disruption'])
        df.loc[i, 'mitigation_action'] = random.choice(['Restore from Backup', 'Incident Response Plan Executed'])
        df.loc[i, 'severity'] = random.choice(['High', 'Critical'])
    elif df.loc[i, 'attack_type'] == 'Phishing':
        df.loc[i, 'attack_vector'] = 'Email'
        df.loc[i, 'impact_level'] = random.choice(['Data Breach', 'Reputational Damage'])

# Output the CSV content
csv_output = df.to_csv(index=False)
print(csv_output)
# Out:
# incident_id,timestamp,attack_type,attack_vector,severity,source_country,target_country,source_ip,device_affected,operating_system,target_system,protocol,port,status,detected_by,impact_level,mitigation_action
# INC00001,2025-05-15 06:26:07,Zero-day Exploit,Cloud Misconfiguration,Medium,USA,Canada,191.106.12.7,Cloud Instance,Linux (Ubuntu),Network Infrastructure,SSH,3389,Containment,SIEM,System Downtime,Isolate System
# INC00002,2025-05-19 14:26:07,Malware,Network Vulnerability,High,India,USA,189.127.107.218,Workstation,macOS,Laboratory Information System (LIS),HTTPS,80,Eradicated,Security Team,Data Breach,Isolate System
# INC00003,2025-07-07 09:03:07,Ransomware,Web Application,High,USA,Canada,178.70.35.23,IoT Sensor,Android,Radiology PACS,HTTPS,1433,Mitigated,Threat Intelligence,Operational Disruption,Restore from Backup
# INC00004,2025-11-09 07:09:07,XSS,Email,High,India,France,187.67.137.215,Server,Linux (Ubuntu),Billing System,SSH,25,Mitigated,User Report,Patient Care Interruption,Incident Response Plan Executed
# INC00005,2025-04-28 04:44:07,DDoS,Network Vulnerability,High,North Korea,Germany,215.220.182.119,Workstation,Windows Server 2019,Electronic Health Records (EHR),SSH,21,Detected,Threat Intelligence,Operational Disruption,Restore from Backup
# INC00006,2025-01-06 00:43:07,DDoS,Cloud Misconfiguration,Low,Brazil,France,208.238.16.212,IoT Sensor,Linux (Ubuntu),Laboratory Information System (LIS),RDP,53,Mitigated,SIEM,Data Breach,Block IP
# INC00007,2025-05-03 15:58:07,Zero-day Exploit,IoT Device,Low,China,Canada,95.64.16.8,Cloud Instance,Android,Patient Monitoring,FTP,3389,Detected,Security Team,Patient Care Interruption,Isolate System
# INC00008,2025-03-11 21:10:07,Phishing,Email,Low,Russia,Australia,207.118.234.149,IoT Sensor,Linux (Ubuntu),Network Infrastructure,SFTP,3389,Containment,Security Team,Reputational Damage,Restore from Backup
# INC00009,2025-02-18 15:02:07,Malware,IoT Device,Low,India,Japan,244.144.48.47,Server,Windows 10,Radiology PACS,HL7,3389,Eradicated,Antivirus,Operational Disruption,Patch Vulnerability
# INC00010,2025-06-15 04:19:07,Malware,IoT Device,Low,China,USA,25.49.144.15,Database Server,Android,Billing System,HL7,443,Eradicated,Security Team,Patient Care Interruption,Incident Response Plan Executed
# INC00011,2025-08-09 21:21:07,Ransomware,Physical Access,High,Germany,UK,9.16.226.44,IoT Sensor,Windows 10,Patient Monitoring,HL7,21,Detected,Threat Intelligence,Operational Disruption,Restore from Backup
# INC00012,2025-03-07 23:20:07,Insider Threat,Physical Access,Low,Brazil,USA,110.133.42.103,Workstation,Android,Laboratory Information System (LIS),HTTPS,21,Detected,User Report,Patient Care Interruption,Restore from Backup
# INC00013,2025-09-11 22:07:07,Phishing,Email,Medium,UK,South Korea,52.55.2.51,Database Server,Windows Server 2019,Laboratory Information System (LIS),RDP,445,Mitigated,Antivirus,Data Breach,Isolate System
# INC00014,2025-11-10 21:36:07,Insider Threat,IoT Device,Low,Brazil,Germany,184.6.26.224,Workstation,Linux (RedHat),Patient Monitoring,HTTP,443,Recovered,Threat Intelligence,Financial Loss,Restore from Backup
# INC00015,2025-03-15 06:46:07,Insider Threat,Email,Medium,Brazil,Japan,238.197.120.247,IoT Sensor,Linux (Ubuntu),Network Infrastructure,DICOM,445,Eradicated,Security Team,Reputational Damage,Forensic Investigation
# INC00016,2025-07-10 19:17:07,Man-in-the-Middle,Physical Access,Medium,Iran,USA,176.77.45.162,Network Router,iOS,Network Infrastructure,HTTPS,22,Ongoing,Firewall,Financial Loss,Isolate System
# INC00017,2025-06-22 06:20:07,XSS,Web Application,Medium,Brazil,Germany,199.91.228.158,Database Server,Linux (Ubuntu),Electronic Health Records (EHR),HL7,22,Detected,User Report,Patient Care Interruption,Restore from Backup
# INC00018,2025-06-20 05:46:07,Zero-day Exploit,Web Application,Low,Brazil,UK,133.30.65.133,Database Server,Linux (RedHat),Network Infrastructure,SSH,21,Recovered,Firewall,Reputational Damage,Restore from Backup
# INC00019,2025-12-22 17:04:07,Insider Threat,Cloud Misconfiguration,Low,Germany,Australia,108.193.186.77,Database Server,macOS,Billing System,FTP,443,Mitigated,Threat Intelligence,System Downtime,Patch Vulnerability
# INC00020,2025-05-30 02:35:07,Ransomware,IoT Device,Critical,China,USA,146.249.68.119,Cloud Instance,Windows 10,Electronic Health Records (EHR),FTP,443,Detected,Antivirus,Data Breach,Restore from Backup
# INC00021,2025-06-30 07:13:07,Malware,Cloud Misconfiguration,Medium,USA,South Korea,178.76.197.204,Cloud Instance,Linux (RedHat),Network Infrastructure,SFTP,80,Detected,Firewall,System Downtime,Forensic Investigation
# INC00022,2025-12-05 02:36:07,Phishing,Email,Medium,Canada,Australia,218.99.25.112,Database Server,Linux (Ubuntu),Billing System,HTTPS,445,Mitigated,IDS/IPS,Reputational Damage,Restore from Backup
# INC00023,2025-09-02 11:16:07,XSS,Email,Low,North Korea,UK,152.176.48.200,Medical Device,macOS,Radiology PACS,FTP,1433,Detected,Security Team,Operational Disruption,Patch Vulnerability
# INC00024,2025-07-23 03:20:07,Man-in-the-Middle,IoT Device,Medium,India,Canada,25.221.249.58,Medical Device,Android,Electronic Health Records (EHR),SFTP,53,Containment,User Report,Operational Disruption,Block IP
# INC00025,2025-12-24 16:37:07,Insider Threat,Physical Access,Low,Iran,Australia,234.202.234.134,Workstation,Windows 10,Patient Monitoring,HTTPS,80,Mitigated,Firewall,Reputational Damage,Reset Passwords
# INC00026,2025-07-12 05:11:07,Insider Threat,Network Vulnerability,High,Russia,Canada,152.36.217.28,Workstation,Windows Server 2019,Billing System,SFTP,21,Detected,IDS/IPS,Financial Loss,Restore from Backup
# INC00027,2025-09-19 07:33:07,Insider Threat,Email,High,Germany,Germany,38.149.204.45,IoT Sensor,Windows 10,Network Infrastructure,HTTPS,53,Eradicated,SIEM,Reputational Damage,Patch Vulnerability
# INC00028,2025-05-11 00:31:07,XSS,IoT Device,Critical,Iran,USA,219.91.180.176,Medical Device,Windows Server 2019,Laboratory Information System (LIS),HTTPS,25,Detected,Firewall,System Downtime,Incident Response Plan Executed
# INC00029,2025-09-24 09:52:07,XSS,Web Application,Low,USA,Germany,23.249.151.103,Cloud Instance,Linux (RedHat),Laboratory Information System (LIS),HTTPS,1433,Containment,User Report,Data Breach,Reset Passwords
# INC00030,2025-10-26 19:35:07,Ransomware,Email,Critical,North Korea,UK,22.195.104.49,Server,Windows 10,Network Infrastructure,RDP,1433,Ongoing,IDS/IPS,System Downtime,Incident Response Plan Executed
# INC00031,2025-04-13 02:00:07,Phishing,Email,High,UK,USA,197.142.142.33,IoT Sensor,Windows 10,Patient Monitoring,RDP,22,Detected,Security Team,Reputational Damage,Forensic Investigation
# INC00032,2025-01-07 13:03:07,Brute Force,IoT Device,Low,India,France,39.116.63.94,Workstation,Linux (Ubuntu),Network Infrastructure,HTTPS,443,Mitigated,Threat Intelligence,Operational Disruption,Reset Passwords
# INC00033,2025-01-04 18:28:07,Man-in-the-Middle,Cloud Misconfiguration,Medium,Canada,UK,82.210.27.211,Cloud Instance,Windows Server 2019,Patient Monitoring,HTTPS,22,Ongoing,Firewall,Reputational Damage,Block IP
# INC00034,2025-02-16 18:34:07,Zero-day Exploit,Web Application,Medium,Brazil,USA,114.17.35.249,Server,Windows Server 2019,Network Infrastructure,HTTP,22,Eradicated,Threat Intelligence,Data Breach,Isolate System
# INC00035,2025-11-24 17:45:07,Malware,Cloud Misconfiguration,Low,USA,Japan,146.206.195.27,Cloud Instance,Windows 10,Billing System,HTTPS,53,Ongoing,Firewall,Patient Care Interruption,Isolate System
# INC00036,2025-11-02 09:13:07,Zero-day Exploit,Email,Low,Brazil,France,80.111.219.10,IoT Sensor,macOS,Radiology PACS,HTTP,25,Recovered,IDS/IPS,Data Breach,Block IP
# INC00037,2025-02-25 09:36:07,Man-in-the-Middle,Web Application,Medium,Germany,South Korea,22.201.164.86,Server,iOS,Patient Monitoring,RDP,53,Containment,Threat Intelligence,Patient Care Interruption,Patch Vulnerability
# INC00038,2025-07-01 17:43:07,DDoS,Web Application,Low,Iran,Germany,11.56.1.231,IoT Sensor,Windows Server 2019,Laboratory Information System (LIS),HTTPS,445,Recovered,SIEM,Data Breach,Restore from Backup
# INC00039,2025-05-04 00:37:07,Zero-day Exploit,Email,High,Canada,France,8.163.195.189,Database Server,iOS,Network Infrastructure,SFTP,80,Recovered,Firewall,Data Breach,Patch Vulnerability
# INC00040,2025-07-21 04:32:07,DDoS,Cloud Misconfiguration,Medium,Brazil,Canada,138.184.187.216,Server,Windows 10,Patient Monitoring,HTTPS,22,Eradicated,Firewall,Reputational Damage,Isolate System
# INC00041,2025-06-21 15:43:07,XSS,Cloud Misconfiguration,Medium,Canada,Australia,225.214.68.158,IoT Sensor,Linux (Ubuntu),Network Infrastructure,SFTP,21,Ongoing,SIEM,Reputational Damage,Reset Passwords
# INC00042,2025-07-18 02:24:07,Brute Force,Physical Access,Medium,Russia,Germany,248.220.68.157,Network Router,Windows 10,Patient Monitoring,HTTP,443,Eradicated,IDS/IPS,Operational Disruption,Restore from Backup
# INC00043,2025-06-05 01:55:07,DDoS,Network Vulnerability,High,China,France,98.224.36.9,Medical Device,Linux (RedHat),Network Infrastructure,HL7,443,Eradicated,IDS/IPS,Reputational Damage,Incident Response Plan Executed
# INC00044,2025-05-27 22:10:07,Zero-day Exploit,Cloud Misconfiguration,Low,Russia,USA,197.244.36.230,Database Server,macOS,Patient Monitoring,HTTPS,80,Recovered,IDS/IPS,Financial Loss,Block IP
# INC00045,2025-12-13 16:19:07,Brute Force,Network Vulnerability,Medium,USA,Japan,10.21.56.10,Database Server,Linux (RedHat),Billing System,DICOM,25,Ongoing,IDS/IPS,System Downtime,Block IP
# INC00046,2025-04-29 17:10:07,SQL Injection,IoT Device,Critical,China,France,174.143.239.49,Workstation,Windows Server 2019,Network Infrastructure,RDP,22,Ongoing,Firewall,Data Breach,Restore from Backup
# INC00047,2025-05-19 11:51:07,Man-in-the-Middle,Physical Access,Low,India,Japan,197.163.54.202,Database Server,iOS,Billing System,FTP,443,Containment,Firewall,Patient Care Interruption,Isolate System
# INC00048,2025-03-26 21:41:07,Insider Threat,Email,Low,Germany,Australia,111.104.126.119,IoT Sensor,macOS,Patient Monitoring,SSH,22,Mitigated,User Report,Data Breach,Incident Response Plan Executed
# INC00049,2025-12-29 17:19:07,Malware,Cloud Misconfiguration,Medium,North Korea,France,132.197.177.148,Medical Device,Windows Server 2019,Billing System,SFTP,1433,Containment,User Report,Operational Disruption,Isolate System
# INC00050,2025-03-09 21:41:07,Brute Force,Network Vulnerability,Medium,Iran,France,101.70.210.218,Network Router,macOS,Radiology PACS,RDP,443,Containment,User Report,System Downtime,Patch Vulnerability
# INC00051,2025-05-03 02:26:07,Ransomware,Web Application,Critical,USA,France,194.147.92.162,Network Router,Windows 10,Radiology PACS,HL7,1433,Ongoing,Security Team,System Downtime,Incident Response Plan Executed
# INC00052,2025-04-05 01:11:07,Insider Threat,Email,Low,India,USA,71.78.16.201,Network Router,Windows Server 2019,Network Infrastructure,FTP,22,Recovered,IDS/IPS,Financial Loss,Reset Passwords
# INC00053,2025-03-08 08:19:07,XSS,Network Vulnerability,Low,UK,South Korea,131.29.126.144,Database Server,Windows Server 2019,Radiology PACS,HL7,3389,Containment,SIEM,Reputational Damage,Reset Passwords
# INC00054,2025-08-22 23:39:07,XSS,Physical Access,Medium,UK,Canada,192.92.52.204,Workstation,Windows Server 2019,Laboratory Information System (LIS),DICOM,445,Ongoing,User Report,Operational Disruption,Isolate System
# INC00055,2025-07-05 12:42:07,Brute Force,Cloud Misconfiguration,High,Germany,UK,254.99.240.251,IoT Sensor,Windows Server 2019,Radiology PACS,SFTP,22,Detected,User Report,Patient Care Interruption,Reset Passwords
# INC00056,2025-10-04 13:20:07,Brute Force,Cloud Misconfiguration,Medium,China,UK,59.234.86.193,IoT Sensor,Linux (Ubuntu),Radiology PACS,HL7,445,Ongoing,IDS/IPS,Reputational Damage,Patch Vulnerability
# INC00057,2025-10-12 19:37:07,Brute Force,Cloud Misconfiguration,Medium,North Korea,Canada,97.15.115.190,Workstation,Linux (RedHat),Electronic Health Records (EHR),HL7,53,Eradicated,IDS/IPS,Reputational Damage,Restore from Backup
# INC00058,2025-11-18 20:55:07,Brute Force,Email,Low,India,USA,52.82.81.84,Medical Device,macOS,Network Infrastructure,SSH,80,Eradicated,Firewall,Operational Disruption,Block IP
# INC00059,2025-04-28 15:06:07,XSS,Email,Low,Canada,Canada,192.61.31.107,Cloud Instance,Windows 10,Billing System,FTP,443,Detected,SIEM,Financial Loss,Patch Vulnerability
# INC00060,2025-01-28 02:49:07,Brute Force,Physical Access,Medium,Canada,South Korea,65.159.65.216,Database Server,iOS,Electronic Health Records (EHR),RDP,21,Recovered,Security Team,Reputational Damage,Forensic Investigation
# INC00061,2025-12-09 11:36:07,Phishing,Email,Medium,Canada,Japan,75.227.133.238,Server,Linux (RedHat),Network Infrastructure,SFTP,443,Mitigated,SIEM,Reputational Damage,Forensic Investigation
# INC00062,2025-05-09 10:42:07,Malware,Cloud Misconfiguration,High,Canada,USA,29.17.244.194,Network Router,Windows Server 2019,Electronic Health Records (EHR),RDP,22,Recovered,Antivirus,System Downtime,Patch Vulnerability
# INC00063,2025-08-25 06:13:07,Phishing,Email,Medium,USA,Japan,223.156.113.128,Cloud Instance,Windows Server 2019,Billing System,FTP,53,Mitigated,Firewall,Data Breach,Restore from Backup
# INC00064,2025-07-19 07:42:07,Phishing,Email,Medium,Canada,UK,15.5.10.101,Cloud Instance,Linux (RedHat),Radiology PACS,SSH,80,Mitigated,Firewall,Reputational Damage,Patch Vulnerability
# INC00065,2025-11-23 03:37:07,XSS,Cloud Misconfiguration,Low,UK,France,125.44.109.1,Server,Android,Billing System,FTP,3389,Eradicated,User Report,Patient Care Interruption,Isolate System
# INC00066,2025-07-30 01:39:07,Man-in-the-Middle,Physical Access,Critical,Iran,UK,71.14.84.234,Server,macOS,Electronic Health Records (EHR),RDP,445,Ongoing,User Report,Financial Loss,Restore from Backup
# INC00067,2025-07-27 09:54:07,SQL Injection,Web Application,High,USA,Australia,179.36.245.215,Server,Windows 10,Radiology PACS,RDP,22,Containment,Firewall,Operational Disruption,Reset Passwords
# INC00068,2025-08-14 19:37:07,Brute Force,Email,Critical,China,Australia,180.210.205.223,Server,Linux (RedHat),Laboratory Information System (LIS),HTTPS,445,Recovered,IDS/IPS,Reputational Damage,Forensic Investigation
# INC00069,2025-02-01 17:03:07,Ransomware,Email,High,Brazil,Germany,12.39.118.81,Cloud Instance,Android,Laboratory Information System (LIS),SSH,80,Detected,Threat Intelligence,System Downtime,Incident Response Plan Executed
# INC00070,2025-12-29 21:18:07,Man-in-the-Middle,Network Vulnerability,Medium,Iran,Australia,89.72.219.132,Medical Device,Linux (Ubuntu),Laboratory Information System (LIS),SSH,1433,Eradicated,Firewall,Financial Loss,Isolate System
# INC00071,2025-06-25 11:32:07,Malware,Email,High,North Korea,Germany,110.57.201.157,Server,Android,Billing System,DICOM,445,Recovered,Antivirus,Reputational Damage,Block IP
# INC00072,2025-05-17 09:03:07,SQL Injection,Cloud Misconfiguration,Medium,North Korea,South Korea,4.174.105.200,Server,Windows 10,Radiology PACS,HTTPS,445,Containment,Threat Intelligence,Operational Disruption,Patch Vulnerability
# INC00073,2025-05-14 02:29:07,Brute Force,Network Vulnerability,Medium,UK,USA,151.140.73.33,Database Server,macOS,Patient Monitoring,HL7,22,Mitigated,Firewall,Patient Care Interruption,Block IP
# INC00074,2025-10-22 23:06:07,SQL Injection,Cloud Misconfiguration,High,India,Australia,189.47.44.249,Server,Linux (RedHat),Network Infrastructure,HL7,25,Mitigated,Threat Intelligence,Reputational Damage,Reset Passwords
# INC00075,2025-04-06 23:31:07,DDoS,Email,Low,North Korea,Canada,187.89.135.142,Server,iOS,Laboratory Information System (LIS),DICOM,80,Detected,Firewall,Financial Loss,Forensic Investigation
# INC00076,2025-02-05 15:22:07,XSS,IoT Device,Low,UK,Japan,46.185.18.10,Workstation,Windows 10,Laboratory Information System (LIS),DICOM,53,Recovered,User Report,Reputational Damage,Block IP
# INC00077,2025-07-23 22:17:07,Phishing,Email,Low,USA,USA,42.207.130.131,Workstation,macOS,Electronic Health Records (EHR),SFTP,1433,Eradicated,Security Team,Data Breach,Block IP
# INC00078,2025-03-02 20:16:07,DDoS,Email,Medium,Brazil,France,26.105.71.163,Network Router,Android,Billing System,HL7,53,Recovered,Firewall,Reputational Damage,Isolate System
# INC00079,2025-02-28 21:04:07,Ransomware,Web Application,Critical,China,Canada,55.201.39.178,Medical Device,macOS,Network Infrastructure,HL7,445,Ongoing,Firewall,System Downtime,Incident Response Plan Executed
# INC00080,2025-04-16 22:53:07,Brute Force,Network Vulnerability,High,Russia,Japan,178.97.200.74,Cloud Instance,Windows 10,Patient Monitoring,HTTP,22,Eradicated,User Report,System Downtime,Incident Response Plan Executed
# INC00081,2025-03-14 13:34:07,Zero-day Exploit,Email,Medium,China,Australia,6.210.224.122,Network Router,Linux (RedHat),Laboratory Information System (LIS),HL7,443,Containment,Threat Intelligence,Patient Care Interruption,Restore from Backup
# INC00082,2025-05-10 03:45:07,XSS,IoT Device,Medium,North Korea,Japan,146.118.119.123,Network Router,macOS,Billing System,DICOM,3389,Recovered,SIEM,Reputational Damage,Restore from Backup
# INC00083,2025-07-29 16:13:07,DDoS,Email,Medium,UK,Japan,153.252.112.99,Cloud Instance,Linux (RedHat),Network Infrastructure,SSH,3389,Detected,Security Team,Patient Care Interruption,Incident Response Plan Executed
# INC00084,2025-07-21 11:39:07,Zero-day Exploit,Cloud Misconfiguration,Low,North Korea,South Korea,235.121.27.227,IoT Sensor,Windows Server 2019,Patient Monitoring,DICOM,53,Containment,User Report,Operational Disruption,Isolate System
# INC00085,2025-04-22 09:29:07,Man-in-the-Middle,Cloud Misconfiguration,Medium,Russia,USA,76.145.118.50,Network Router,Linux (Ubuntu),Billing System,FTP,80,Mitigated,Threat Intelligence,System Downtime,Isolate System
# INC00086,2025-05-10 07:27:07,Insider Threat,Email,Low,Russia,USA,108.86.129.79,Workstation,Linux (Ubuntu),Electronic Health Records (EHR),HL7,53,Containment,SIEM,Patient Care Interruption,Incident Response Plan Executed
# INC00087,2025-10-09 19:52:07,Phishing,Email,High,Germany,UK,208.52.180.111,IoT Sensor,Windows Server 2019,Billing System,HTTPS,3389,Mitigated,Security Team,Reputational Damage,Patch Vulnerability
# INC00088,2025-12-06 15:34:07,DDoS,Cloud Misconfiguration,High,Brazil,UK,29.179.162.204,Workstation,Linux (RedHat),Network Infrastructure,HTTPS,53,Mitigated,Antivirus,Operational Disruption,Block IP
# INC00089,2025-04-05 03:42:07,Insider Threat,Cloud Misconfiguration,High,Brazil,Japan,25.111.109.62,Database Server,Linux (RedHat),Laboratory Information System (LIS),FTP,443,Ongoing,IDS/IPS,Data Breach,Isolate System
# INC00090,2025-06-29 17:19:07,Brute Force,Email,Medium,Canada,Germany,42.249.239.155,Medical Device,Linux (RedHat),Electronic Health Records (EHR),HTTP,25,Ongoing,Firewall,System Downtime,Isolate System
# INC00091,2025-09-14 16:51:07,Phishing,Email,Critical,Germany,France,35.77.54.62,IoT Sensor,Android,Network Infrastructure,RDP,445,Containment,Firewall,Reputational Damage,Block IP
# INC00092,2025-11-03 20:12:07,Brute Force,Web Application,Low,USA,France,60.15.31.9,Network Router,Linux (RedHat),Network Infrastructure,HTTP,445,Ongoing,Antivirus,System Downtime,Block IP
# INC00093,2025-07-11 12:06:07,Insider Threat,Cloud Misconfiguration,High,USA,UK,54.250.140.125,Workstation,Linux (Ubuntu),Radiology PACS,HTTPS,445,Mitigated,IDS/IPS,Operational Disruption,Forensic Investigation
# INC00094,2025-10-04 01:48:07,Man-in-the-Middle,Email,Critical,UK,Germany,33.133.111.135,Network Router,Linux (Ubuntu),Laboratory Information System (LIS),FTP,3389,Containment,Threat Intelligence,Reputational Damage,Restore from Backup
# INC00095,2025-05-29 08:06:07,Brute Force,IoT Device,Low,Germany,USA,206.23.72.64,Cloud Instance,Windows Server 2019,Electronic Health Records (EHR),HTTP,1433,Ongoing,SIEM,Operational Disruption,Reset Passwords
# INC00096,2025-07-18 22:15:07,Brute Force,Cloud Misconfiguration,High,Brazil,France,57.118.227.213,IoT Sensor,Linux (Ubuntu),Patient Monitoring,RDP,80,Detected,Security Team,Patient Care Interruption,Restore from Backup
# INC00097,2025-11-11 14:34:07,Phishing,Email,Low,India,Canada,248.34.175.97,Network Router,iOS,Electronic Health Records (EHR),RDP,443,Detected,Antivirus,Reputational Damage,Patch Vulnerability
# INC00098,2025-09-06 07:13:07,Brute Force,Physical Access,Low,North Korea,USA,74.152.134.8,Medical Device,Linux (Ubuntu),Laboratory Information System (LIS),SSH,443,Ongoing,Firewall,System Downtime,Reset Passwords
# INC00099,2025-11-02 13:04:07,Ransomware,Physical Access,High,Russia,Australia,59.170.92.199,Network Router,macOS,Patient Monitoring,HTTPS,445,Containment,Firewall,Data Breach,Restore from Backup
# INC00100,2025-01-04 15:51:07,Brute Force,Physical Access,High,Germany,Germany,119.118.159.110,IoT Sensor,Windows 10,Billing System,SFTP,53,Recovered,SIEM,System Downtime,Forensic Investigation
# INC00101,2025-01-30 04:38:07,Ransomware,Cloud Misconfiguration,Critical,Canada,Japan,165.245.216.40,Cloud Instance,Linux (RedHat),Radiology PACS,RDP,445,Recovered,Firewall,Operational Disruption,Incident Response Plan Executed
# INC00102,2025-10-29 07:13:07,Brute Force,Web Application,Low,UK,UK,103.182.15.24,Network Router,Windows Server 2019,Network Infrastructure,HTTP,443,Ongoing,Firewall,Reputational Damage,Isolate System
# INC00103,2025-07-08 11:55:07,Zero-day Exploit,Network Vulnerability,Medium,Brazil,Australia,72.112.139.133,Workstation,Windows Server 2019,Network Infrastructure,HTTP,25,Detected,Antivirus,Data Breach,Patch Vulnerability
# INC00104,2025-06-18 17:40:07,XSS,IoT Device,Critical,UK,Australia,23.93.120.237,Network Router,Linux (RedHat),Patient Monitoring,FTP,53,Detected,Threat Intelligence,Financial Loss,Block IP
# INC00105,2025-08-02 07:56:07,Man-in-the-Middle,Cloud Misconfiguration,Medium,China,France,151.88.189.229,Network Router,Windows Server 2019,Electronic Health Records (EHR),FTP,53,Detected,Threat Intelligence,System Downtime,Incident Response Plan Executed
# INC00106,2025-12-02 09:06:07,Zero-day Exploit,Cloud Misconfiguration,Medium,North Korea,South Korea,117.119.111.73,IoT Sensor,Android,Radiology PACS,DICOM,3389,Eradicated,Firewall,Patient Care Interruption,Restore from Backup
# INC00107,2025-05-29 07:01:07,Ransomware,IoT Device,Critical,Russia,Australia,54.65.113.222,Medical Device,Windows Server 2019,Patient Monitoring,HL7,80,Recovered,Firewall,Data Breach,Incident Response Plan Executed
# INC00108,2025-03-04 05:27:07,Ransomware,Cloud Misconfiguration,Critical,China,Japan,19.110.9.205,Server,iOS,Billing System,SFTP,80,Detected,Antivirus,Data Breach,Restore from Backup
# INC00109,2025-11-27 08:55:07,Man-in-the-Middle,Cloud Misconfiguration,Medium,Canada,Japan,211.162.73.1,Medical Device,Linux (RedHat),Radiology PACS,FTP,22,Detected,Firewall,Data Breach,Restore from Backup
# INC00110,2025-05-04 11:01:07,Malware,Cloud Misconfiguration,Low,North Korea,Germany,28.116.81.142,Network Router,Windows 10,Radiology PACS,FTP,445,Recovered,Threat Intelligence,System Downtime,Forensic Investigation
# INC00111,2025-12-08 20:24:07,XSS,IoT Device,Critical,China,Canada,28.83.38.47,Medical Device,macOS,Billing System,DICOM,53,Detected,Threat Intelligence,Data Breach,Forensic Investigation
# INC00112,2025-06-07 14:04:07,SQL Injection,Email,Medium,Russia,Canada,129.86.9.229,Workstation,Android,Patient Monitoring,RDP,53,Detected,Firewall,System Downtime,Restore from Backup
# INC00113,2025-03-01 07:47:07,DDoS,Web Application,Low,North Korea,South Korea,155.136.97.248,Cloud Instance,Windows 10,Patient Monitoring,HTTP,443,Recovered,Threat Intelligence,Patient Care Interruption,Restore from Backup
# INC00114,2025-04-05 15:42:07,Ransomware,Physical Access,High,India,Germany,117.31.97.223,Server,Android,Laboratory Information System (LIS),DICOM,53,Eradicated,IDS/IPS,Data Breach,Restore from Backup
# INC00115,2025-05-28 13:53:07,Malware,Cloud Misconfiguration,Medium,North Korea,Australia,197.12.71.57,Database Server,macOS,Laboratory Information System (LIS),SSH,53,Recovered,Antivirus,System Downtime,Reset Passwords
# INC00116,2025-01-21 03:38:07,Man-in-the-Middle,Physical Access,Medium,China,South Korea,1.111.45.187,IoT Sensor,iOS,Laboratory Information System (LIS),SFTP,443,Ongoing,Security Team,Reputational Damage,Block IP
# INC00117,2025-08-05 16:26:07,Insider Threat,Network Vulnerability,Critical,China,Australia,164.173.190.248,IoT Sensor,Linux (RedHat),Billing System,RDP,443,Eradicated,Antivirus,Reputational Damage,Restore from Backup
# INC00118,2025-06-27 18:19:07,Brute Force,IoT Device,Medium,Russia,South Korea,95.12.25.254,Database Server,Linux (Ubuntu),Patient Monitoring,HL7,21,Containment,IDS/IPS,Data Breach,Patch Vulnerability
# INC00119,2025-09-22 02:20:07,Malware,Email,High,Germany,USA,174.241.130.230,Database Server,macOS,Electronic Health Records (EHR),FTP,445,Detected,Antivirus,System Downtime,Restore from Backup
# INC00120,2025-12-31 03:39:07,DDoS,Email,Medium,Brazil,South Korea,245.167.187.85,Server,iOS,Radiology PACS,HTTP,22,Recovered,Security Team,Patient Care Interruption,Isolate System
# INC00121,2025-03-15 20:47:07,Ransomware,Email,High,Iran,UK,222.223.84.222,Database Server,Linux (RedHat),Network Infrastructure,SSH,3389,Mitigated,Firewall,Operational Disruption,Restore from Backup
# INC00122,2025-09-14 18:22:07,Man-in-the-Middle,Cloud Misconfiguration,High,China,UK,222.84.242.232,Database Server,Linux (Ubuntu),Patient Monitoring,SFTP,443,Ongoing,User Report,Patient Care Interruption,Forensic Investigation
# INC00123,2025-03-04 16:21:07,Malware,Web Application,Low,Iran,Australia,13.241.178.32,IoT Sensor,Linux (RedHat),Patient Monitoring,DICOM,53,Recovered,Firewall,Data Breach,Isolate System
# INC00124,2025-10-20 06:41:07,Zero-day Exploit,Network Vulnerability,High,Germany,Japan,227.36.221.217,Database Server,Linux (RedHat),Network Infrastructure,SFTP,443,Mitigated,IDS/IPS,Patient Care Interruption,Isolate System
# INC00125,2025-06-15 13:52:07,Malware,Network Vulnerability,Medium,Germany,Germany,203.197.180.240,Server,Windows 10,Network Infrastructure,HTTP,443,Mitigated,Security Team,Financial Loss,Block IP
# INC00126,2025-10-21 02:51:07,Ransomware,Physical Access,High,UK,Australia,39.86.59.1,Medical Device,macOS,Network Infrastructure,DICOM,3389,Recovered,SIEM,Operational Disruption,Incident Response Plan Executed
# INC00127,2025-04-02 16:01:07,Insider Threat,IoT Device,Medium,USA,Japan,61.94.175.167,Database Server,Linux (Ubuntu),Radiology PACS,SFTP,443,Detected,Antivirus,Patient Care Interruption,Block IP
# INC00128,2025-05-22 02:53:07,Insider Threat,Network Vulnerability,Low,Germany,Japan,244.221.62.130,Server,macOS,Patient Monitoring,HTTPS,443,Recovered,IDS/IPS,Patient Care Interruption,Restore from Backup
# INC00129,2025-09-04 09:04:07,Malware,Network Vulnerability,Low,UK,Australia,247.33.16.159,Workstation,Linux (Ubuntu),Network Infrastructure,RDP,80,Ongoing,User Report,Reputational Damage,Reset Passwords
# INC00130,2025-07-14 11:12:07,Zero-day Exploit,Web Application,High,Russia,France,137.62.41.126,Workstation,Windows 10,Laboratory Information System (LIS),DICOM,443,Eradicated,User Report,Reputational Damage,Reset Passwords
# INC00131,2025-11-24 03:48:07,Insider Threat,Web Application,Low,Iran,Germany,237.202.196.35,Network Router,Android,Radiology PACS,SFTP,80,Mitigated,Security Team,Patient Care Interruption,Incident Response Plan Executed
# INC00132,2025-05-06 20:34:07,Brute Force,Cloud Misconfiguration,Low,Iran,Australia,166.150.142.168,Network Router,iOS,Laboratory Information System (LIS),DICOM,3389,Containment,IDS/IPS,Data Breach,Reset Passwords
# INC00133,2025-11-23 14:02:07,XSS,Cloud Misconfiguration,Low,North Korea,Germany,83.19.57.94,Cloud Instance,macOS,Billing System,SFTP,445,Eradicated,SIEM,Data Breach,Restore from Backup
# INC00134,2025-09-02 08:06:07,SQL Injection,Cloud Misconfiguration,Medium,Brazil,France,24.241.170.96,Cloud Instance,iOS,Patient Monitoring,HL7,443,Eradicated,Firewall,Data Breach,Block IP
# INC00135,2025-05-18 07:46:07,Malware,IoT Device,Low,China,Canada,197.31.188.88,Database Server,Windows 10,Network Infrastructure,RDP,53,Eradicated,Antivirus,Reputational Damage,Incident Response Plan Executed
# INC00136,2025-10-31 11:55:07,Malware,Network Vulnerability,High,Brazil,Japan,13.87.11.146,IoT Sensor,Linux (Ubuntu),Radiology PACS,RDP,445,Detected,SIEM,System Downtime,Patch Vulnerability
# INC00137,2025-02-21 14:45:07,SQL Injection,IoT Device,Medium,Brazil,USA,134.142.245.93,Workstation,Windows 10,Laboratory Information System (LIS),FTP,80,Detected,Firewall,Operational Disruption,Forensic Investigation
# INC00138,2025-01-28 17:33:07,Insider Threat,Web Application,Low,China,South Korea,232.129.197.228,Workstation,iOS,Laboratory Information System (LIS),SFTP,80,Containment,SIEM,Patient Care Interruption,Incident Response Plan Executed
# INC00139,2025-10-09 11:40:07,Zero-day Exploit,IoT Device,Low,USA,Japan,145.141.219.75,Network Router,macOS,Electronic Health Records (EHR),RDP,443,Detected,IDS/IPS,Data Breach,Block IP
# INC00140,2025-05-03 03:48:07,XSS,Cloud Misconfiguration,Critical,USA,South Korea,174.106.194.101,Database Server,macOS,Network Infrastructure,HTTP,443,Eradicated,Firewall,Financial Loss,Patch Vulnerability
# INC00141,2025-05-04 22:06:07,Insider Threat,Network Vulnerability,High,USA,Germany,123.10.64.227,IoT Sensor,Android,Radiology PACS,HL7,80,Eradicated,User Report,Data Breach,Restore from Backup
# INC00142,2025-09-24 19:51:07,Brute Force,Physical Access,Low,Iran,UK,234.140.67.237,Server,Linux (Ubuntu),Patient Monitoring,DICOM,22,Detected,Security Team,System Downtime,Block IP
# INC00143,2025-05-14 05:04:07,Brute Force,Web Application,Medium,Russia,Canada,6.102.91.171,Network Router,Android,Billing System,RDP,53,Eradicated,User Report,Patient Care Interruption,Forensic Investigation
# INC00144,2025-03-05 16:33:07,XSS,Cloud Misconfiguration,Low,Canada,UK,91.203.30.92,Network Router,Linux (RedHat),Billing System,DICOM,445,Ongoing,Firewall,Patient Care Interruption,Restore from Backup
# INC00145,2025-02-08 15:24:07,Malware,Cloud Misconfiguration,High,Canada,USA,166.127.105.249,Workstation,macOS,Network Infrastructure,HTTPS,80,Eradicated,User Report,Financial Loss,Block IP
# INC00146,2025-01-14 18:54:07,Phishing,Email,Medium,UK,UK,65.56.16.232,Workstation,Linux (RedHat),Billing System,DICOM,443,Recovered,Antivirus,Reputational Damage,Block IP
# INC00147,2025-08-21 01:51:07,Insider Threat,Network Vulnerability,Medium,North Korea,Australia,215.38.15.248,Database Server,Linux (RedHat),Patient Monitoring,SFTP,3389,Recovered,User Report,Financial Loss,Reset Passwords
# INC00148,2025-11-14 04:53:07,Zero-day Exploit,IoT Device,Medium,India,USA,162.114.172.142,Network Router,iOS,Billing System,HL7,25,Detected,IDS/IPS,Data Breach,Restore from Backup
# INC00149,2025-06-15 20:36:07,Zero-day Exploit,Email,Low,Brazil,France,90.2.169.187,Workstation,Windows 10,Electronic Health Records (EHR),SFTP,3389,Ongoing,Antivirus,Reputational Damage,Reset Passwords
# INC00150,2025-07-03 21:38:07,XSS,Network Vulnerability,Critical,USA,Canada,37.12.224.211,Workstation,iOS,Billing System,RDP,80,Containment,IDS/IPS,Reputational Damage,Forensic Investigation
# INC00151,2025-08-22 07:24:07,Zero-day Exploit,IoT Device,Medium,Germany,Germany,229.73.148.189,Workstation,Linux (RedHat),Electronic Health Records (EHR),HTTPS,25,Ongoing,IDS/IPS,System Downtime,Isolate System
# INC00152,2025-07-20 12:18:07,Phishing,Email,Low,China,Japan,219.95.15.230,Server,Windows 10,Network Infrastructure,HTTPS,443,Eradicated,SIEM,Reputational Damage,Forensic Investigation
# INC00153,2025-12-19 15:05:07,Malware,Cloud Misconfiguration,Low,Brazil,Germany,2.27.90.7,Medical Device,Linux (RedHat),Radiology PACS,DICOM,53,Mitigated,Firewall,Operational Disruption,Incident Response Plan Executed
# INC00154,2025-04-30 00:15:07,DDoS,IoT Device,Critical,China,South Korea,171.157.97.173,Network Router,Windows 10,Laboratory Information System (LIS),FTP,21,Mitigated,Antivirus,Patient Care Interruption,Forensic Investigation
# INC00155,2025-03-18 11:44:07,DDoS,Network Vulnerability,Critical,Brazil,Canada,65.40.43.190,Server,macOS,Billing System,FTP,80,Mitigated,Antivirus,Financial Loss,Reset Passwords
# INC00156,2025-05-23 21:54:07,XSS,Network Vulnerability,Low,Brazil,Japan,200.79.246.229,Network Router,Android,Patient Monitoring,SFTP,445,Mitigated,IDS/IPS,Operational Disruption,Isolate System
# INC00157,2025-12-03 07:58:07,Man-in-the-Middle,Physical Access,Medium,Iran,South Korea,49.44.209.141,Server,Windows 10,Billing System,SFTP,21,Containment,Firewall,Operational Disruption,Incident Response Plan Executed
# INC00158,2025-12-06 09:01:07,Man-in-the-Middle,Physical Access,High,Canada,UK,119.144.236.69,Cloud Instance,Windows 10,Patient Monitoring,RDP,21,Mitigated,IDS/IPS,System Downtime,Patch Vulnerability
# INC00159,2025-10-14 04:17:07,Brute Force,Network Vulnerability,Medium,China,USA,65.84.101.42,Cloud Instance,iOS,Electronic Health Records (EHR),FTP,445,Eradicated,Security Team,Operational Disruption,Restore from Backup
# INC00160,2025-11-26 00:04:07,Malware,Physical Access,Low,Iran,Germany,199.123.95.172,Database Server,iOS,Radiology PACS,HL7,1433,Recovered,Security Team,Patient Care Interruption,Patch Vulnerability
# INC00161,2025-01-14 08:35:07,XSS,IoT Device,Low,Canada,France,198.48.44.19,Workstation,iOS,Patient Monitoring,HL7,445,Eradicated,Security Team,Operational Disruption,Restore from Backup
# INC00162,2025-05-05 16:13:07,Insider Threat,Cloud Misconfiguration,Medium,USA,USA,189.84.50.36,IoT Sensor,macOS,Laboratory Information System (LIS),HTTP,445,Ongoing,Antivirus,System Downtime,Reset Passwords
# INC00163,2025-06-06 18:12:07,XSS,Network Vulnerability,Medium,India,USA,102.99.70.86,Workstation,Android,Electronic Health Records (EHR),HTTP,445,Mitigated,User Report,Operational Disruption,Patch Vulnerability
# INC00164,2025-03-24 22:33:07,Phishing,Email,Low,China,Canada,31.173.114.227,IoT Sensor,Windows 10,Billing System,HTTP,3389,Mitigated,User Report,Data Breach,Block IP
# INC00165,2025-12-10 17:56:07,XSS,Web Application,Low,Germany,USA,215.157.27.158,Server,Linux (RedHat),Patient Monitoring,SFTP,80,Detected,User Report,Financial Loss,Forensic Investigation
# INC00166,2025-08-26 03:38:07,Man-in-the-Middle,Network Vulnerability,Critical,Brazil,Australia,196.40.36.182,Workstation,Android,Network Infrastructure,DICOM,53,Containment,Firewall,Reputational Damage,Isolate System
# INC00167,2025-08-22 16:30:07,Brute Force,Physical Access,High,North Korea,Canada,102.108.186.25,Medical Device,Linux (Ubuntu),Laboratory Information System (LIS),SSH,25,Eradicated,Security Team,Operational Disruption,Reset Passwords
# INC00168,2025-02-08 12:33:07,Malware,Network Vulnerability,Medium,Iran,Canada,242.162.128.240,Cloud Instance,Linux (RedHat),Patient Monitoring,HTTP,22,Mitigated,IDS/IPS,Patient Care Interruption,Forensic Investigation
# INC00169,2025-08-23 04:47:07,Man-in-the-Middle,Web Application,Low,UK,Germany,139.67.19.192,Cloud Instance,iOS,Billing System,SSH,53,Mitigated,User Report,Operational Disruption,Block IP
# INC00170,2025-04-18 01:43:07,Phishing,Email,High,North Korea,Australia,191.138.51.246,Workstation,Linux (Ubuntu),Patient Monitoring,HL7,80,Eradicated,User Report,Reputational Damage,Reset Passwords
# INC00171,2025-06-01 22:00:07,Insider Threat,Physical Access,Medium,Canada,Germany,49.207.43.174,IoT Sensor,iOS,Billing System,HTTPS,443,Recovered,User Report,Reputational Damage,Forensic Investigation
# INC00172,2025-07-01 14:48:07,Ransomware,Physical Access,High,China,Canada,135.104.181.119,Database Server,macOS,Billing System,HTTP,80,Containment,Antivirus,Operational Disruption,Restore from Backup
# INC00173,2025-04-20 23:28:07,SQL Injection,Web Application,Low,Canada,Australia,99.92.41.196,Cloud Instance,iOS,Electronic Health Records (EHR),HTTPS,1433,Containment,IDS/IPS,Operational Disruption,Block IP
# INC00174,2025-03-07 19:31:07,Malware,Email,Critical,UK,France,232.146.151.137,Workstation,Windows 10,Network Infrastructure,HL7,443,Eradicated,SIEM,Patient Care Interruption,Forensic Investigation
# INC00175,2025-10-17 20:24:07,Ransomware,IoT Device,Critical,Canada,South Korea,205.193.165.102,Network Router,Windows Server 2019,Laboratory Information System (LIS),DICOM,80,Eradicated,User Report,System Downtime,Restore from Backup
# INC00176,2025-03-15 23:33:07,Brute Force,Physical Access,Medium,Iran,USA,132.146.133.187,Workstation,iOS,Billing System,SFTP,3389,Detected,Firewall,Patient Care Interruption,Reset Passwords
# INC00177,2025-01-19 14:32:07,Brute Force,Web Application,Medium,Germany,Australia,81.52.158.86,IoT Sensor,macOS,Patient Monitoring,HL7,443,Eradicated,Firewall,Financial Loss,Incident Response Plan Executed
# INC00178,2025-03-14 22:13:07,Malware,Physical Access,Medium,UK,Germany,120.190.156.29,Network Router,Linux (Ubuntu),Network Infrastructure,SFTP,1433,Eradicated,Security Team,Patient Care Interruption,Incident Response Plan Executed
# INC00179,2025-06-02 05:49:07,Malware,IoT Device,Low,India,UK,43.147.45.2,Network Router,Android,Electronic Health Records (EHR),SFTP,445,Detected,IDS/IPS,Data Breach,Patch Vulnerability
# INC00180,2025-07-31 13:04:07,Phishing,Email,Low,Brazil,Canada,117.88.105.93,IoT Sensor,Linux (RedHat),Laboratory Information System (LIS),SSH,22,Eradicated,Threat Intelligence,Reputational Damage,Forensic Investigation
# INC00181,2025-12-07 06:23:07,Zero-day Exploit,Email,Low,Germany,Germany,44.39.29.31,IoT Sensor,Windows 10,Radiology PACS,SFTP,3389,Mitigated,User Report,Operational Disruption,Block IP
# INC00182,2025-05-15 00:02:07,XSS,Web Application,High,Brazil,Germany,141.67.129.109,IoT Sensor,macOS,Billing System,FTP,25,Detected,Security Team,System Downtime,Block IP
# INC00183,2025-12-06 20:26:07,Malware,Email,High,Russia,USA,23.220.97.159,Database Server,macOS,Network Infrastructure,RDP,80,Mitigated,IDS/IPS,Patient Care Interruption,Restore from Backup
# INC00184,2025-11-20 04:43:07,Brute Force,Web Application,High,Iran,Germany,236.180.250.152,IoT Sensor,Linux (Ubuntu),Billing System,DICOM,25,Recovered,SIEM,Operational Disruption,Incident Response Plan Executed
# INC00185,2025-09-22 15:04:07,Zero-day Exploit,Network Vulnerability,Critical,Russia,South Korea,70.249.21.77,Database Server,Windows Server 2019,Network Infrastructure,HTTPS,25,Eradicated,User Report,Operational Disruption,Incident Response Plan Executed
# INC00186,2025-10-07 17:03:07,Malware,IoT Device,Low,Brazil,Australia,177.30.48.25,IoT Sensor,iOS,Patient Monitoring,FTP,443,Mitigated,Security Team,Patient Care Interruption,Forensic Investigation
# INC00187,2025-10-26 08:00:07,XSS,Email,Medium,China,France,99.63.27.112,Server,Windows Server 2019,Radiology PACS,DICOM,21,Containment,Threat Intelligence,Patient Care Interruption,Isolate System
# INC00188,2025-09-28 09:22:07,Man-in-the-Middle,Network Vulnerability,High,China,Germany,33.196.26.202,Workstation,Linux (RedHat),Laboratory Information System (LIS),HTTP,21,Eradicated,Firewall,Patient Care Interruption,Isolate System
# INC00189,2025-05-13 13:34:07,Insider Threat,Email,Medium,Iran,South Korea,250.233.201.122,Workstation,iOS,Laboratory Information System (LIS),RDP,443,Eradicated,Threat Intelligence,Reputational Damage,Forensic Investigation
# INC00190,2025-01-13 15:26:07,XSS,Network Vulnerability,Medium,China,Germany,215.109.213.170,Database Server,Windows 10,Patient Monitoring,HL7,22,Mitigated,Antivirus,Financial Loss,Isolate System
# INC00191,2025-10-08 03:53:07,XSS,IoT Device,Low,China,Canada,54.105.116.22,Cloud Instance,iOS,Network Infrastructure,SFTP,443,Mitigated,User Report,Data Breach,Block IP
# INC00192,2025-10-02 13:07:07,XSS,Physical Access,Medium,UK,Germany,12.216.76.94,IoT Sensor,iOS,Network Infrastructure,SFTP,443,Detected,Antivirus,Reputational Damage,Patch Vulnerability
# INC00193,2025-01-25 11:17:07,Malware,Web Application,Critical,India,USA,13.13.121.81,Medical Device,Android,Billing System,HTTPS,3389,Ongoing,Firewall,Operational Disruption,Isolate System
# INC00194,2025-02-26 19:27:07,Malware,Network Vulnerability,High,North Korea,Japan,193.117.156.183,Server,Linux (Ubuntu),Billing System,FTP,53,Ongoing,IDS/IPS,Financial Loss,Reset Passwords
# INC00195,2025-07-28 13:47:07,Phishing,Email,Medium,Germany,Canada,217.243.177.226,Workstation,Linux (RedHat),Electronic Health Records (EHR),SSH,80,Ongoing,User Report,Reputational Damage,Forensic Investigation
# INC00196,2025-01-16 07:58:07,Malware,Network Vulnerability,High,Brazil,France,29.2.237.26,IoT Sensor,Windows 10,Patient Monitoring,HL7,53,Eradicated,Security Team,Operational Disruption,Isolate System
# INC00197,2025-03-23 00:06:07,Malware,Network Vulnerability,Low,UK,Australia,230.49.209.216,Cloud Instance,Windows Server 2019,Network Infrastructure,DICOM,21,Recovered,Firewall,Patient Care Interruption,Patch Vulnerability
# INC00198,2025-10-01 04:05:07,Ransomware,Cloud Misconfiguration,High,Canada,USA,113.148.19.212,Cloud Instance,macOS,Radiology PACS,HL7,22,Detected,User Report,System Downtime,Incident Response Plan Executed
# INC00199,2025-05-06 22:28:07,Brute Force,Web Application,Low,Canada,UK,4.8.135.120,Workstation,Windows 10,Network Infrastructure,SSH,25,Containment,Firewall,Patient Care Interruption,Patch Vulnerability
# INC00200,2025-10-02 23:00:07,XSS,Physical Access,High,Russia,South Korea,144.159.106.181,Network Router,iOS,Laboratory Information System (LIS),DICOM,1433,Detected,SIEM,Data Breach,Restore from Backup
# INC00201,2025-01-31 16:52:07,Brute Force,Network Vulnerability,Low,Canada,Canada,161.83.152.208,Workstation,Linux (RedHat),Electronic Health Records (EHR),HTTPS,443,Mitigated,Security Team,Data Breach,Patch Vulnerability
# INC00202,2025-12-25 07:03:07,Zero-day Exploit,IoT Device,Critical,Iran,France,235.154.37.229,IoT Sensor,Windows 10,Patient Monitoring,HTTP,1433,Recovered,Firewall,Patient Care Interruption,Block IP
# INC00203,2025-11-17 09:26:07,Ransomware,Email,Critical,Canada,Canada,78.190.172.125,Workstation,iOS,Patient Monitoring,HL7,21,Detected,Threat Intelligence,Operational Disruption,Restore from Backup
# INC00204,2025-08-08 03:00:07,Man-in-the-Middle,Cloud Misconfiguration,Low,USA,South Korea,74.25.254.115,IoT Sensor,iOS,Patient Monitoring,HTTPS,443,Mitigated,SIEM,Reputational Damage,Patch Vulnerability
# INC00205,2025-12-20 13:03:07,Ransomware,Cloud Misconfiguration,High,Brazil,USA,85.63.37.178,Server,macOS,Billing System,RDP,53,Detected,Firewall,Operational Disruption,Incident Response Plan Executed
# INC00206,2025-01-25 03:28:07,Brute Force,IoT Device,Low,Russia,Australia,198.100.21.228,Server,Linux (Ubuntu),Electronic Health Records (EHR),SSH,21,Detected,Security Team,Financial Loss,Restore from Backup
# INC00207,2025-03-23 05:07:07,Malware,Email,Low,North Korea,South Korea,69.227.91.193,Workstation,macOS,Billing System,HL7,445,Detected,Threat Intelligence,Operational Disruption,Restore from Backup
# INC00208,2025-01-29 05:55:07,Insider Threat,Email,Medium,USA,UK,172.185.8.172,Workstation,Windows 10,Radiology PACS,DICOM,443,Ongoing,IDS/IPS,Patient Care Interruption,Reset Passwords
# INC00209,2025-03-19 23:34:07,Zero-day Exploit,Cloud Misconfiguration,Low,Germany,France,135.77.108.72,Medical Device,Windows Server 2019,Laboratory Information System (LIS),FTP,22,Mitigated,User Report,Financial Loss,Incident Response Plan Executed
# INC00210,2025-02-23 06:07:07,Malware,Cloud Misconfiguration,Medium,Russia,Australia,43.96.148.28,Cloud Instance,Linux (Ubuntu),Billing System,RDP,443,Containment,SIEM,Reputational Damage,Block IP
# INC00211,2025-03-14 15:19:07,XSS,Cloud Misconfiguration,Low,Brazil,Canada,191.58.58.38,Medical Device,Android,Patient Monitoring,SFTP,21,Eradicated,SIEM,Reputational Damage,Reset Passwords
# INC00212,2025-05-20 23:04:07,SQL Injection,Physical Access,Low,Brazil,Canada,29.142.34.153,Network Router,Linux (RedHat),Electronic Health Records (EHR),FTP,3389,Mitigated,Security Team,Patient Care Interruption,Block IP
# INC00213,2025-09-27 19:57:07,XSS,Web Application,Critical,UK,South Korea,99.22.72.198,IoT Sensor,Android,Laboratory Information System (LIS),SFTP,445,Mitigated,Antivirus,System Downtime,Patch Vulnerability
# INC00214,2025-03-05 16:56:07,Man-in-the-Middle,Web Application,Low,Canada,USA,34.249.125.73,Cloud Instance,Windows Server 2019,Patient Monitoring,SSH,25,Mitigated,User Report,Patient Care Interruption,Restore from Backup
# INC00215,2025-10-25 01:53:07,Insider Threat,Email,Critical,Brazil,France,165.63.102.20,Cloud Instance,Windows 10,Radiology PACS,SSH,80,Ongoing,IDS/IPS,Patient Care Interruption,Block IP
# INC00216,2025-09-13 22:27:07,Ransomware,Physical Access,Critical,China,Australia,59.211.239.28,Cloud Instance,Windows Server 2019,Electronic Health Records (EHR),HTTP,80,Mitigated,IDS/IPS,System Downtime,Restore from Backup
# INC00217,2025-12-16 20:51:07,XSS,Web Application,Medium,Canada,UK,198.45.127.224,Cloud Instance,iOS,Network Infrastructure,FTP,21,Containment,Antivirus,Financial Loss,Patch Vulnerability
# INC00218,2025-02-28 13:18:07,Malware,Network Vulnerability,Critical,Iran,South Korea,43.105.185.8,IoT Sensor,macOS,Network Infrastructure,DICOM,445,Containment,Antivirus,Reputational Damage,Isolate System
# INC00219,2025-12-29 08:50:07,Man-in-the-Middle,Cloud Misconfiguration,Medium,Russia,UK,175.190.105.86,Cloud Instance,Windows 10,Electronic Health Records (EHR),SFTP,80,Ongoing,User Report,Patient Care Interruption,Forensic Investigation
# INC00220,2025-12-18 21:38:07,SQL Injection,Web Application,Medium,UK,South Korea,200.115.93.156,Network Router,macOS,Patient Monitoring,HL7,80,Ongoing,Firewall,Patient Care Interruption,Patch Vulnerability
# INC00221,2025-10-09 16:35:07,XSS,Web Application,High,UK,USA,35.141.127.42,Database Server,macOS,Patient Monitoring,FTP,53,Containment,Threat Intelligence,Patient Care Interruption,Forensic Investigation
# INC00222,2025-06-10 22:12:07,Zero-day Exploit,Physical Access,Medium,North Korea,USA,203.188.110.110,Network Router,Linux (Ubuntu),Electronic Health Records (EHR),HL7,445,Ongoing,Antivirus,System Downtime,Reset Passwords
# INC00223,2025-01-12 00:00:07,Brute Force,IoT Device,Medium,Brazil,South Korea,120.58.102.98,Workstation,Linux (RedHat),Radiology PACS,RDP,1433,Mitigated,Antivirus,Patient Care Interruption,Block IP
# INC00224,2025-10-06 12:42:07,Man-in-the-Middle,Network Vulnerability,High,Russia,South Korea,228.253.254.167,Database Server,Linux (RedHat),Network Infrastructure,HTTPS,22,Recovered,Security Team,Operational Disruption,Reset Passwords
# INC00225,2025-02-03 06:21:07,Man-in-the-Middle,Email,Low,India,USA,13.177.35.73,Workstation,Linux (Ubuntu),Laboratory Information System (LIS),RDP,22,Ongoing,SIEM,Patient Care Interruption,Forensic Investigation
# INC00226,2025-12-26 16:00:07,Zero-day Exploit,IoT Device,Medium,Germany,Australia,184.232.10.105,Workstation,iOS,Laboratory Information System (LIS),RDP,80,Ongoing,Security Team,Operational Disruption,Isolate System
# INC00227,2025-05-14 18:53:07,Insider Threat,IoT Device,Medium,China,Germany,207.74.244.244,Server,Android,Patient Monitoring,HTTP,3389,Eradicated,Firewall,Patient Care Interruption,Incident Response Plan Executed
# INC00228,2025-10-30 21:14:07,Man-in-the-Middle,Physical Access,High,UK,South Korea,144.33.223.157,Database Server,macOS,Electronic Health Records (EHR),HL7,1433,Ongoing,Security Team,Patient Care Interruption,Patch Vulnerability
# INC00229,2025-04-28 04:49:07,SQL Injection,IoT Device,Low,Brazil,South Korea,137.229.92.188,Server,Windows Server 2019,Laboratory Information System (LIS),SSH,445,Eradicated,Security Team,Reputational Damage,Incident Response Plan Executed
# INC00230,2025-12-18 16:15:07,Zero-day Exploit,Cloud Misconfiguration,Medium,Canada,USA,51.15.202.38,Cloud Instance,Android,Billing System,HTTP,1433,Mitigated,Antivirus,Financial Loss,Reset Passwords
# INC00231,2025-08-20 23:21:07,Phishing,Email,Medium,Brazil,France,115.51.7.60,Medical Device,Linux (RedHat),Billing System,HTTP,445,Eradicated,Security Team,Reputational Damage,Isolate System
# INC00232,2025-09-30 17:31:07,DDoS,Cloud Misconfiguration,Low,Iran,South Korea,139.104.4.146,IoT Sensor,Linux (Ubuntu),Billing System,HTTPS,53,Mitigated,Threat Intelligence,System Downtime,Block IP
# INC00233,2025-07-14 15:54:07,Insider Threat,Network Vulnerability,High,USA,USA,148.11.236.237,Workstation,Linux (Ubuntu),Network Infrastructure,SSH,25,Ongoing,SIEM,Patient Care Interruption,Reset Passwords
# ...
# INC00273,2025-12-15 08:43:07,XSS,Physical Access,Low,Germany,South Korea,203.201.191.30,Server,Android,Patient Monitoring,HTTP,443,Eradicated,Threat Intelligence,Reputational Damage,Restore from Backup
# INC00274,2025-08-28 03:26:07,Man-in-the-Middle,IoT Device,High,India,Canada,81.23.224.178,Database Server,Linux (RedHat),Laboratory Information System (LIS),FTP,445,Eradicated,Antivirus,Data Breach,Block IP
# INC00275,2025-10-26 22:41:07,Brute Force,Web Application,High,Canada,Canada,62.204.189.216,IoT Sensor,Windows 10,Electronic Health Records (EHR),DICOM,1433,Ongoing,IDS/IPS,Patient Care Interruption,Incident Response Plan Executed
# INC00276,2025-03-04 03:47:07,Zero-day Exploit,Email,High,Iran,Germany,65.217.237.97,IoT Sensor,Linux (Ubuntu),Radiology PACS,SSH,80,Mitigated,IDS/IPS,Financial Loss,Isolate System
# INC00277,2025-11-02 05:58:07,XSS,Physical Access,High,North Korea,Canada,161.217.229.159,Workstation,Linux (Ubuntu),Billing System,HTTP,53,Containment,Security Team,Financial Loss,Patch Vulnerability
# INC00278,2025-05-06 21:49:07,Man-in-the-Middle,Cloud Misconfiguration,Low,North Korea,Japan,38.71.244.171,Network Router,iOS,Patient Monitoring,HL7,25,Recovered,Antivirus,Reputational Damage,Forensic Investigation
# INC00279,2025-02-13 17:25:07,Zero-day Exploit,Physical Access,Medium,Brazil,Australia,129.116.16.99,Server,macOS,Laboratory Information System (LIS),FTP,443,Eradicated,Threat Intelligence,Patient Care Interruption,Reset Passwords
# INC00280,2025-05-15 01:17:07,Phishing,Email,High,China,Germany,132.149.148.171,Network Router,Windows Server 2019,Billing System,SFTP,25,Mitigated,Antivirus,Reputational Damage,Isolate System
# INC00281,2025-06-04 19:01:07,SQL Injection,Email,Low,Russia,USA,238.218.129.8,Server,Windows 10,Electronic Health Records (EHR),DICOM,443,Eradicated,Antivirus,Data Breach,Forensic Investigation
# INC00282,2025-09-02 09:42:07,DDoS,Email,Medium,Brazil,Australia,217.21.126.231,Workstation,Linux (Ubuntu),Laboratory Information System (LIS),RDP,80,Recovered,SIEM,Reputational Damage,Isolate System
# INC00283,2025-06-17 10:13:07,Insider Threat,Network Vulnerability,High,Germany,Germany,69.175.30.2,Cloud Instance,iOS,Electronic Health Records (EHR),FTP,25,Detected,User Report,Operational Disruption,Forensic Investigation
# INC00284,2025-07-16 06:59:07,DDoS,Cloud Misconfiguration,Low,UK,Canada,136.103.220.158,Workstation,iOS,Electronic Health Records (EHR),SSH,443,Containment,Firewall,Reputational Damage,Reset Passwords
# INC00285,2025-10-02 10:13:07,Zero-day Exploit,Email,Medium,UK,Australia,38.165.86.190,Network Router,iOS,Patient Monitoring,FTP,22,Ongoing,Threat Intelligence,Reputational Damage,Forensic Investigation
# INC00286,2025-06-15 03:19:07,XSS,Email,High,India,Australia,148.160.107.182,Workstation,Windows 10,Network Infrastructure,SSH,443,Eradicated,SIEM,Data Breach,Isolate System
# INC00287,2025-08-07 01:45:07,XSS,Web Application,Low,Germany,Australia,147.166.135.252,Network Router,macOS,Network Infrastructure,HL7,53,Mitigated,IDS/IPS,System Downtime,Isolate System
# INC00288,2025-06-01 19:05:07,Brute Force,Web Application,Medium,Canada,UK,130.102.247.178,Workstation,Windows 10,Network Infrastructure,SSH,443,Containment,Security Team,Patient Care Interruption,Restore from Backup
# INC00289,2025-04-19 20:56:07,XSS,Email,Critical,India,Germany,211.57.109.47,Workstation,Windows 10,Billing System,DICOM,1433,Mitigated,User Report,Reputational Damage,Reset Passwords
# INC00290,2025-05-17 05:33:07,XSS,Web Application,Medium,Canada,Japan,55.224.104.104,Cloud Instance,iOS,Billing System,HTTP,22,Containment,Antivirus,Patient Care Interruption,Restore from Backup
# INC00291,2025-03-25 19:00:07,XSS,Web Application,Critical,UK,Germany,196.156.60.3,Network Router,Linux (RedHat),Laboratory Information System (LIS),HTTP,80,Containment,Security Team,Financial Loss,Reset Passwords
# INC00292,2025-11-19 12:38:07,Insider Threat,IoT Device,High,India,Australia,245.48.201.208,Cloud Instance,Windows Server 2019,Billing System,SFTP,1433,Recovered,Firewall,Operational Disruption,Isolate System
# INC00293,2025-01-06 06:30:07,SQL Injection,Physical Access,Medium,India,Australia,154.127.100.213,IoT Sensor,Windows Server 2019,Radiology PACS,FTP,1433,Recovered,Antivirus,Data Breach,Incident Response Plan Executed
# INC00294,2025-11-01 03:06:07,SQL Injection,Web Application,Medium,Canada,Canada,89.121.71.138,Workstation,iOS,Radiology PACS,RDP,21,Recovered,Antivirus,System Downtime,Restore from Backup
# INC00295,2025-03-16 16:18:07,DDoS,Web Application,High,Brazil,Japan,146.32.150.50,IoT Sensor,Windows 10,Electronic Health Records (EHR),DICOM,3389,Ongoing,User Report,Financial Loss,Reset Passwords
# INC00296,2025-06-06 12:34:07,Ransomware,Web Application,Critical,UK,South Korea,89.34.29.27,Medical Device,Windows Server 2019,Electronic Health Records (EHR),SFTP,443,Containment,User Report,Operational Disruption,Restore from Backup
# INC00297,2025-04-30 21:21:07,Zero-day Exploit,Network Vulnerability,High,Iran,Australia,209.254.12.222,Database Server,Linux (Ubuntu),Network Infrastructure,DICOM,21,Recovered,Threat Intelligence,Financial Loss,Block IP
# INC00298,2025-11-27 17:16:07,Man-in-the-Middle,Network Vulnerability,Medium,Russia,Japan,116.143.63.167,Network Router,Android,Radiology PACS,SFTP,53,Ongoing,Threat Intelligence,Reputational Damage,Incident Response Plan Executed
# INC00299,2025-10-10 10:38:07,Man-in-the-Middle,Physical Access,Low,China,Japan,130.32.162.22,IoT Sensor,macOS,Billing System,HTTP,53,Mitigated,SIEM,Patient Care Interruption,Reset Passwords
# INC00300,2025-05-03 03:10:07,Phishing,Email,High,Germany,UK,160.143.122.196,Server,Windows Server 2019,Patient Monitoring,HTTP,53,Containment,User Report,Reputational Damage,Patch Vulnerability
# INC00301,2025-07-14 00:49:07,SQL Injection,Web Application,High,Iran,USA,109.151.78.73,Workstation,macOS,Patient Monitoring,HTTPS,80,Mitigated,IDS/IPS,Data Breach,Block IP
# INC00302,2025-03-09 11:23:07,Zero-day Exploit,IoT Device,High,China,Canada,241.13.237.58,Network Router,Linux (Ubuntu),Electronic Health Records (EHR),HTTPS,445,Detected,Antivirus,Patient Care Interruption,Forensic Investigation
# INC00303,2025-03-11 06:47:07,Man-in-the-Middle,Physical Access,Low,Russia,UK,160.124.192.12,IoT Sensor,Android,Electronic Health Records (EHR),HL7,22,Mitigated,User Report,Financial Loss,Patch Vulnerability
# INC00304,2025-04-22 16:12:07,Brute Force,Network Vulnerability,Low,Germany,UK,6.132.86.118,Server,Linux (Ubuntu),Laboratory Information System (LIS),HL7,22,Ongoing,Security Team,System Downtime,Patch Vulnerability
# INC00305,2025-01-14 18:42:07,Man-in-the-Middle,IoT Device,High,UK,Germany,14.12.20.66,Workstation,Android,Laboratory Information System (LIS),HTTPS,22,Ongoing,Antivirus,System Downtime,Isolate System
# INC00306,2025-05-19 21:50:07,SQL Injection,IoT Device,Low,Canada,France,238.23.80.119,Network Router,macOS,Electronic Health Records (EHR),HL7,25,Containment,User Report,Data Breach,Incident Response Plan Executed
# INC00307,2025-01-09 03:57:07,SQL Injection,Network Vulnerability,Critical,Brazil,Canada,20.106.48.10,Network Router,Android,Electronic Health Records (EHR),HL7,22,Detected,Antivirus,Reputational Damage,Forensic Investigation
# INC00308,2025-09-22 18:46:07,Malware,Web Application,Low,Germany,Japan,106.174.180.95,IoT Sensor,Windows 10,Network Infrastructure,RDP,3389,Mitigated,Antivirus,Data Breach,Restore from Backup
# INC00309,2025-09-12 07:39:07,XSS,Cloud Misconfiguration,Medium,North Korea,France,54.199.190.80,Server,Windows 10,Laboratory Information System (LIS),HTTPS,80,Recovered,Firewall,Patient Care Interruption,Incident Response Plan Executed
# INC00310,2025-05-07 02:43:07,XSS,Physical Access,Low,USA,South Korea,220.29.173.202,Network Router,Windows Server 2019,Patient Monitoring,SFTP,445,Containment,Threat Intelligence,System Downtime,Isolate System
# INC00311,2025-06-21 19:51:07,Man-in-the-Middle,IoT Device,Critical,China,UK,199.135.239.127,Cloud Instance,iOS,Network Infrastructure,FTP,25,Mitigated,IDS/IPS,Data Breach,Block IP
# INC00312,2025-09-24 08:44:07,Phishing,Email,Medium,USA,UK,194.147.52.84,Medical Device,Windows 10,Patient Monitoring,SFTP,53,Eradicated,Firewall,Reputational Damage,Reset Passwords
# INC00313,2025-10-16 21:30:07,Brute Force,Network Vulnerability,Low,Brazil,USA,46.207.134.63,Database Server,Android,Radiology PACS,HTTP,25,Recovered,Firewall,Data Breach,Forensic Investigation
# INC00314,2025-11-06 20:51:07,Ransomware,Email,High,North Korea,Germany,186.157.130.115,Server,Windows 10,Electronic Health Records (EHR),SSH,3389,Ongoing,Security Team,System Downtime,Restore from Backup
# INC00315,2025-06-10 15:55:07,Zero-day Exploit,Email,Medium,Germany,South Korea,63.31.240.38,Network Router,Windows 10,Laboratory Information System (LIS),RDP,445,Detected,Threat Intelligence,Data Breach,Restore from Backup
# INC00316,2025-02-21 14:38:07,Man-in-the-Middle,Network Vulnerability,Medium,Germany,USA,19.206.238.228,Database Server,Linux (Ubuntu),Electronic Health Records (EHR),DICOM,3389,Recovered,Security Team,Financial Loss,Reset Passwords
# INC00317,2025-06-22 19:17:07,Man-in-the-Middle,Cloud Misconfiguration,High,Russia,Japan,1.70.235.226,Medical Device,Windows Server 2019,Patient Monitoring,HTTP,25,Recovered,SIEM,Reputational Damage,Isolate System
# INC00318,2025-06-01 05:55:07,DDoS,Web Application,High,UK,Canada,187.244.201.233,Workstation,Windows 10,Laboratory Information System (LIS),HL7,80,Eradicated,SIEM,Data Breach,Block IP
# INC00319,2025-12-17 01:44:07,XSS,Network Vulnerability,Critical,Germany,UK,57.13.223.7,Database Server,macOS,Billing System,DICOM,25,Detected,Threat Intelligence,Data Breach,Reset Passwords
# INC00320,2025-08-04 16:51:07,Phishing,Email,Medium,Brazil,USA,52.51.19.220,Database Server,Windows 10,Network Infrastructure,SSH,25,Mitigated,User Report,Reputational Damage,Isolate System
# INC00321,2025-05-07 16:36:07,XSS,Web Application,Medium,Brazil,Australia,26.157.58.115,IoT Sensor,Android,Radiology PACS,RDP,22,Mitigated,Antivirus,Data Breach,Patch Vulnerability
# INC00322,2025-09-11 18:08:07,XSS,Physical Access,Medium,Canada,UK,56.120.212.54,Cloud Instance,Linux (RedHat),Laboratory Information System (LIS),FTP,443,Detected,Threat Intelligence,Patient Care Interruption,Incident Response Plan Executed
# INC00323,2025-10-27 12:09:07,DDoS,Cloud Misconfiguration,Medium,North Korea,Japan,140.237.80.194,IoT Sensor,Windows Server 2019,Billing System,SSH,22,Detected,IDS/IPS,Operational Disruption,Block IP
# INC00324,2025-11-25 00:30:07,Insider Threat,Email,Medium,India,Germany,34.11.186.56,Workstation,Linux (RedHat),Electronic Health Records (EHR),HL7,21,Mitigated,IDS/IPS,Patient Care Interruption,Block IP
# INC00325,2025-09-07 12:35:07,Ransomware,Email,High,Russia,Canada,2.191.252.143,Workstation,Android,Patient Monitoring,HTTP,1433,Containment,IDS/IPS,Data Breach,Incident Response Plan Executed
# INC00326,2025-07-02 06:37:07,XSS,Cloud Misconfiguration,Critical,China,France,230.49.153.47,Server,iOS,Patient Monitoring,SFTP,22,Eradicated,Firewall,Reputational Damage,Incident Response Plan Executed
# INC00327,2025-06-21 15:11:07,Brute Force,Email,Low,China,Germany,102.193.168.231,Workstation,Windows Server 2019,Billing System,HTTPS,80,Detected,Threat Intelligence,Reputational Damage,Block IP
# INC00328,2025-08-11 14:59:07,Phishing,Email,Low,India,Germany,105.0.126.10,Workstation,Android,Electronic Health Records (EHR),HTTP,445,Containment,IDS/IPS,Reputational Damage,Restore from Backup
# INC00329,2025-12-28 18:08:07,Insider Threat,Email,Medium,China,South Korea,179.205.178.136,Cloud Instance,Windows 10,Billing System,DICOM,3389,Detected,IDS/IPS,Operational Disruption,Forensic Investigation
# INC00330,2025-06-30 04:34:07,Zero-day Exploit,Email,Medium,China,Australia,94.152.9.19,Medical Device,Windows Server 2019,Billing System,SSH,443,Containment,IDS/IPS,Financial Loss,Isolate System
# INC00331,2025-10-22 01:35:07,Man-in-the-Middle,Physical Access,Low,North Korea,Germany,2.109.229.100,Workstation,Windows Server 2019,Radiology PACS,HTTP,1433,Mitigated,SIEM,Reputational Damage,Restore from Backup
# INC00332,2025-06-17 00:20:07,SQL Injection,Email,Critical,USA,USA,31.163.18.7,Database Server,macOS,Laboratory Information System (LIS),HTTP,3389,Recovered,SIEM,Financial Loss,Restore from Backup
# INC00333,2025-12-18 08:57:07,Phishing,Email,Low,UK,France,227.20.29.108,Workstation,Linux (Ubuntu),Patient Monitoring,HTTP,443,Containment,SIEM,Data Breach,Reset Passwords
# INC00334,2025-02-16 19:08:07,XSS,Physical Access,Critical,Iran,USA,186.189.195.89,Workstation,Android,Billing System,HL7,22,Ongoing,User Report,Patient Care Interruption,Isolate System
# INC00335,2025-11-30 13:15:07,Brute Force,IoT Device,Low,Germany,Canada,199.208.215.43,Server,Android,Billing System,FTP,445,Containment,Security Team,Financial Loss,Incident Response Plan Executed
# INC00336,2025-05-06 14:21:07,Brute Force,IoT Device,Low,UK,Canada,185.224.73.231,Network Router,Windows 10,Laboratory Information System (LIS),HL7,21,Detected,SIEM,Operational Disruption,Restore from Backup
# INC00337,2025-11-19 12:14:07,SQL Injection,Network Vulnerability,Medium,Russia,Australia,5.100.132.168,Workstation,Linux (RedHat),Radiology PACS,HTTPS,443,Mitigated,IDS/IPS,System Downtime,Forensic Investigation
# INC00338,2025-05-05 22:27:07,SQL Injection,Network Vulnerability,Low,Iran,Japan,4.77.172.238,IoT Sensor,Android,Billing System,SSH,443,Detected,Threat Intelligence,Data Breach,Patch Vulnerability
# INC00339,2025-04-17 23:53:07,Insider Threat,Physical Access,Low,Russia,Japan,192.124.238.4,Cloud Instance,Windows Server 2019,Electronic Health Records (EHR),SFTP,53,Recovered,Threat Intelligence,System Downtime,Restore from Backup
# INC00340,2025-10-31 19:19:07,Brute Force,IoT Device,Low,North Korea,USA,64.53.204.135,Workstation,Linux (RedHat),Patient Monitoring,SSH,1433,Recovered,Firewall,Operational Disruption,Restore from Backup
# INC00341,2025-05-03 21:26:07,Man-in-the-Middle,IoT Device,Critical,Canada,USA,148.210.219.100,Medical Device,Linux (Ubuntu),Laboratory Information System (LIS),HTTPS,1433,Ongoing,IDS/IPS,Financial Loss,Block IP
# INC00342,2025-10-29 06:44:07,SQL Injection,Physical Access,Low,India,Japan,184.245.119.7,Server,macOS,Billing System,DICOM,25,Ongoing,Firewall,System Downtime,Patch Vulnerability
# INC00343,2025-12-22 01:07:07,Brute Force,Cloud Misconfiguration,Low,Canada,UK,14.171.209.240,Network Router,Linux (Ubuntu),Electronic Health Records (EHR),HL7,21,Containment,Antivirus,Patient Care Interruption,Block IP
# INC00344,2025-04-14 09:28:07,Ransomware,Cloud Misconfiguration,Critical,Germany,Australia,113.118.206.158,Cloud Instance,Windows 10,Network Infrastructure,SFTP,21,Mitigated,Firewall,Data Breach,Restore from Backup
# INC00345,2025-01-06 14:16:07,Man-in-the-Middle,IoT Device,Medium,Germany,France,154.15.123.36,Cloud Instance,Linux (Ubuntu),Radiology PACS,FTP,25,Recovered,IDS/IPS,Data Breach,Reset Passwords
# INC00346,2025-07-03 07:28:07,SQL Injection,Email,Medium,Brazil,Canada,40.113.157.12,Medical Device,Android,Laboratory Information System (LIS),SSH,443,Mitigated,Firewall,Operational Disruption,Patch Vulnerability
# INC00347,2025-03-20 22:11:07,Insider Threat,IoT Device,Low,North Korea,France,238.138.218.41,Server,Linux (RedHat),Electronic Health Records (EHR),RDP,21,Detected,IDS/IPS,System Downtime,Patch Vulnerability
# INC00348,2025-01-05 03:31:07,SQL Injection,Web Application,Critical,Canada,UK,165.190.66.146,Cloud Instance,iOS,Billing System,DICOM,21,Ongoing,SIEM,Data Breach,Patch Vulnerability
# INC00349,2025-11-04 17:01:07,Insider Threat,IoT Device,Medium,North Korea,France,137.246.119.251,Database Server,Linux (Ubuntu),Patient Monitoring,HTTPS,80,Ongoing,Threat Intelligence,Financial Loss,Patch Vulnerability
# INC00350,2025-07-10 14:02:07,Phishing,Email,Medium,USA,UK,77.7.196.254,Network Router,Windows Server 2019,Network Infrastructure,HL7,25,Mitigated,User Report,Reputational Damage,Incident Response Plan Executed

# %%
# Function to run SQL queries and display results
def run_sql_query(query):
    return pd.read_sql_query(query, conn)

# Verify by querying the table
query = "SELECT * FROM cybersecurity_incidents LIMIT 5;"
result_df = run_sql_query(query)
display(result_df)
# Out:
#   incident_id            timestamp       attack_type           attack_vector  \
# 0    INC00001  2025-05-15 06:26:07  Zero-day Exploit  Cloud Misconfiguration
# 1    INC00002  2025-05-19 14:26:07           Malware   Network Vulnerability
# 2    INC00003  2025-07-07 09:03:07        Ransomware         Web Application
# 3    INC00004  2025-11-09 07:09:07               XSS                   Email
# 4    INC00005  2025-04-28 04:44:07              DDoS   Network Vulnerability
#
#   severity source_country target_country        source_ip device_affected  \
# 0   Medium            USA         Canada     191.106.12.7  Cloud Instance
# 1     High          India            USA  189.127.107.218     Workstation
# 2     High            USA         Canada     178.70.35.23      IoT Sensor
# 3     High          India         France   187.67.137.215          Server
# 4     High    North Korea        Germany  215.220.182.119     Workstation
#
#       operating_system                        target_system protocol  port  \
# 0       Linux (Ubuntu)               Network Infrastructure      SSH  3389
# 1                macOS  Laboratory Information System (LIS)    HTTPS    80
# 2              Android                       Radiology PACS    HTTPS  1433
# 3       Linux (Ubuntu)                       Billing System      SSH    25
# 4  Windows Server 2019      Electronic Health Records (EHR)      SSH    21
#
#         status          detected_by               impact_level  \
# 0  Containment                 SIEM            System Downtime
# 1   Eradicated        Security Team                Data Breach
# 2    Mitigated  Threat Intelligence     Operational Disruption
# 3    Mitigated          User Report  Patient Care Interruption
# 4     Detected  Threat Intelligence     Operational Disruption
#
#                  mitigation_action
# 0                   Isolate System
# 1                   Isolate System
# 2              Restore from Backup
# 3  Incident Response Plan Executed
# 4              Restore from Backup

# %% [markdown]
# **Show the first 10 rows of the dataframe**

# %%
display(df.head(10))
# Out:
#   incident_id            timestamp       attack_type           attack_vector  \
# 0    INC00001  2025-05-15 06:26:07  Zero-day Exploit  Cloud Misconfiguration
# 1    INC00002  2025-05-19 14:26:07           Malware   Network Vulnerability
# 2    INC00003  2025-07-07 09:03:07        Ransomware         Web Application
# 3    INC00004  2025-11-09 07:09:07               XSS                   Email
# 4    INC00005  2025-04-28 04:44:07              DDoS   Network Vulnerability
# 5    INC00006  2025-01-06 00:43:07              DDoS  Cloud Misconfiguration
# 6    INC00007  2025-05-03 15:58:07  Zero-day Exploit              IoT Device
# 7    INC00008  2025-03-11 21:10:07          Phishing                   Email
# 8    INC00009  2025-02-18 15:02:07           Malware              IoT Device
# 9    INC00010  2025-06-15 04:19:07           Malware              IoT Device
#
#   severity source_country target_country        source_ip  device_affected  \
# 0   Medium            USA         Canada     191.106.12.7   Cloud Instance
# 1     High          India            USA  189.127.107.218      Workstation
# 2     High            USA         Canada     178.70.35.23       IoT Sensor
# 3     High          India         France   187.67.137.215           Server
# 4     High    North Korea        Germany  215.220.182.119      Workstation
# 5      Low         Brazil         France   208.238.16.212       IoT Sensor
# 6      Low          China         Canada       95.64.16.8   Cloud Instance
# 7      Low         Russia      Australia  207.118.234.149       IoT Sensor
# 8      Low          India          Japan    244.144.48.47           Server
# 9      Low          China            USA     25.49.144.15  Database Server
#
#       operating_system                        target_system protocol  port  \
# 0       Linux (Ubuntu)               Network Infrastructure      SSH  3389
# 1                macOS  Laboratory Information System (LIS)    HTTPS    80
# 2              Android                       Radiology PACS    HTTPS  1433
# 3       Linux (Ubuntu)                       Billing System      SSH    25
# 4  Windows Server 2019      Electronic Health Records (EHR)      SSH    21
# 5       Linux (Ubuntu)  Laboratory Information System (LIS)      RDP    53
# 6              Android                   Patient Monitoring      FTP  3389
# 7       Linux (Ubuntu)               Network Infrastructure     SFTP  3389
# 8           Windows 10                       Radiology PACS      HL7  3389
# 9              Android                       Billing System      HL7   443
#
#         status          detected_by               impact_level  \
# 0  Containment                 SIEM            System Downtime
# 1   Eradicated        Security Team                Data Breach
# 2    Mitigated  Threat Intelligence     Operational Disruption
# 3    Mitigated          User Report  Patient Care Interruption
# 4     Detected  Threat Intelligence     Operational Disruption
# 5    Mitigated                 SIEM                Data Breach
# 6     Detected        Security Team  Patient Care Interruption
# 7  Containment        Security Team        Reputational Damage
# 8   Eradicated            Antivirus     Operational Disruption
# 9   Eradicated        Security Team  Patient Care Interruption
#
#                  mitigation_action
# 0                   Isolate System
# 1                   Isolate System
# 2              Restore from Backup
# 3  Incident Response Plan Executed
# 4              Restore from Backup
# 5                         Block IP
# 6                   Isolate System
# 7              Restore from Backup
# 8              Patch Vulnerability
# 9  Incident Response Plan Executed

# %% [markdown]
# **Count the occurrences of each attack type**

# %%
query = """SELECT attack_type, COUNT(*) AS occurrence_count FROM cybersecurity_incidents GROUP BY attack_type ORDER BY occurrence_count DESC;"""
result_df = run_sql_query(query)
display(result_df)
# Out:
#          attack_type  occurrence_count
# 0                XSS                50
# 1        Brute Force                45
# 2  Man-in-the-Middle                41
# 3            Malware                38
# 4   Zero-day Exploit                35
# 5     Insider Threat                34
# 6           Phishing                29
# 7         Ransomware                28
# 8      SQL Injection                27
# 9               DDoS                23

# %% [markdown]
# **Analyze the number of cyber attacks based on severity levels.**

# %%
query = """SELECT severity, COUNT(*) AS attack_count FROM cybersecurity_incidents GROUP BY severity ORDER BY attack_count DESC;"""
result_df = run_sql_query(query)
display(result_df)
# Out:
#    severity  attack_count
# 0    Medium           112
# 1       Low           112
# 2      High            79
# 3  Critical            47

# %% [markdown]
# **Retrieve all cyber attacks classified as Low severity.**

# %%
query = """SELECT * FROM cybersecurity_incidents WHERE severity = 'Low';"""
result_df = run_sql_query(query)
display(result_df)
# Out:
#     incident_id            timestamp       attack_type  \
# 0      INC00006  2025-01-06 00:43:07              DDoS
# 1      INC00007  2025-05-03 15:58:07  Zero-day Exploit
# 2      INC00008  2025-03-11 21:10:07          Phishing
# 3      INC00009  2025-02-18 15:02:07           Malware
# 4      INC00010  2025-06-15 04:19:07           Malware
# ..          ...                  ...               ...
# 107    INC00339  2025-04-17 23:53:07    Insider Threat
# 108    INC00340  2025-10-31 19:19:07       Brute Force
# 109    INC00342  2025-10-29 06:44:07     SQL Injection
# 110    INC00343  2025-12-22 01:07:07       Brute Force
# 111    INC00347  2025-03-20 22:11:07    Insider Threat
#
#               attack_vector severity source_country target_country  \
# 0    Cloud Misconfiguration      Low         Brazil         France
# 1                IoT Device      Low          China         Canada
# 2                     Email      Low         Russia      Australia
# 3                IoT Device      Low          India          Japan
# 4                IoT Device      Low          China            USA
# ..                      ...      ...            ...            ...
# 107         Physical Access      Low         Russia          Japan
# 108              IoT Device      Low    North Korea            USA
# 109         Physical Access      Low          India          Japan
# 110  Cloud Misconfiguration      Low         Canada             UK
# 111              IoT Device      Low    North Korea         France
#
#            source_ip  device_affected     operating_system  \
# 0     208.238.16.212       IoT Sensor       Linux (Ubuntu)
# 1         95.64.16.8   Cloud Instance              Android
# 2    207.118.234.149       IoT Sensor       Linux (Ubuntu)
# 3      244.144.48.47           Server           Windows 10
# 4       25.49.144.15  Database Server              Android
# ..               ...              ...                  ...
# 107    192.124.238.4   Cloud Instance  Windows Server 2019
# 108    64.53.204.135      Workstation       Linux (RedHat)
# 109    184.245.119.7           Server                macOS
# 110   14.171.209.240   Network Router       Linux (Ubuntu)
# 111   238.138.218.41           Server       Linux (RedHat)
#
#                            target_system protocol  port       status  \
# 0    Laboratory Information System (LIS)      RDP    53    Mitigated
# 1                     Patient Monitoring      FTP  3389     Detected
# 2                 Network Infrastructure     SFTP  3389  Containment
# 3                         Radiology PACS      HL7  3389   Eradicated
# 4                         Billing System      HL7   443   Eradicated
# ..                                   ...      ...   ...          ...
# 107      Electronic Health Records (EHR)     SFTP    53    Recovered
# 108                   Patient Monitoring      SSH  1433    Recovered
# 109                       Billing System    DICOM    25      Ongoing
# 110      Electronic Health Records (EHR)      HL7    21  Containment
# 111      Electronic Health Records (EHR)      RDP    21     Detected
#
#              detected_by               impact_level  \
# 0                   SIEM                Data Breach
# 1          Security Team  Patient Care Interruption
# 2          Security Team        Reputational Damage
# 3              Antivirus     Operational Disruption
# 4          Security Team  Patient Care Interruption
# ..                   ...                        ...
# 107  Threat Intelligence            System Downtime
# 108             Firewall     Operational Disruption
# 109             Firewall            System Downtime
# 110            Antivirus  Patient Care Interruption
# 111              IDS/IPS            System Downtime
#
#                    mitigation_action
# 0                           Block IP
# 1                     Isolate System
# 2                Restore from Backup
# 3                Patch Vulnerability
# 4    Incident Response Plan Executed
# ..                               ...
# 107              Restore from Backup
# 108              Restore from Backup
# 109              Patch Vulnerability
# 110                         Block IP
# 111              Patch Vulnerability
#
# [112 rows x 17 columns]

# %% [markdown]
# **Analyze cyber attacks based on source country.**

# %%
query = """SELECT source_country, COUNT(*) AS attack_count FROM cybersecurity_incidents GROUP BY source_country ORDER BY attack_count DESC;"""
result_df = run_sql_query(query)
display(result_df)
# Out:
#   source_country  attack_count
# 0         Brazil            45
# 1          China            44
# 2        Germany            40
# 3         Canada            40
# 4             UK            35
# 5    North Korea            34
# 6            USA            31
# 7           Iran            28
# 8         Russia            27
# 9          India            26

# %% [markdown]
# **Identify the most frequently affected devices in cyber attacks.**

# %%
query = """SELECT device_affected, COUNT(*) AS attack_count FROM cybersecurity_incidents GROUP BY device_affected ORDER BY attack_count DESC;"""
result_df = run_sql_query(query)
display(result_df)
# Out:
#    device_affected  attack_count
# 0      Workstation            70
# 1       IoT Sensor            54
# 2   Network Router            53
# 3   Cloud Instance            50
# 4  Database Server            48
# 5           Server            44
# 6   Medical Device            31

# %% [markdown]
# **Analyze the number of successful versus blocked cyber attacks.**

# %%
query = """SELECT status, COUNT(*) AS attack_count FROM cybersecurity_incidents GROUP BY status ORDER BY attack_count DESC;"""
result_df = run_sql_query(query)
display(result_df)
# Out:
#         status  attack_count
# 0    Mitigated            69
# 1   Eradicated            60
# 2     Detected            60
# 3      Ongoing            56
# 4  Containment            54
# 5    Recovered            51
